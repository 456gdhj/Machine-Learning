# %%
class_ =['classA','classB','classC','classD']

# %%
Instance =['classA','classB','classC','classD','classA','classD','classC']

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lebel_encoder = LabelEncoder()

# %%
encoded_labels=lebel_encoder.fit_transform(Instance)

# %%
print("Encodet lables:",encoded_labels)
# Out:
# Encodet lables: [0 1 2 3 0 3 2]

# %%
orginal_labels=lebel_encoder.inverse_transform(encoded_labels)

# %%
print("Orginal labels:",orginal_labels)
# Out:
# Orginal labels: ['classA' 'classB' 'classC' 'classD' 'classA' 'classD' 'classC']
